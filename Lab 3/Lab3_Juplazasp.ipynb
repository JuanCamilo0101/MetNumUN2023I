# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanCamilo0101/MetNumUN2023I/blob/main/Lab%203/Lab3_Juplazasp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Laboratorio 3**
#
# Juan Camilo Plazas Plazas (Juplazasp@unal.edu.co)

# %% [markdown]
# 1.Certificate course: **Python 101 for Data Science**

# %% [markdown]
# ![Screenshot_2.png](data:image/png;base64,...)

# %% [markdown]
# https://courses.cognitiveclass.ai/certificates/73eb1ee8e96349d3ae6cc2d3ed070b94

# %% [markdown]
# 2.Certificate course: **Data Analysis With Python**

# %% [markdown]
# ![Screenshot_3.png](data:image/png;base64,...)

# %% [markdown]
# https://courses.cognitiveclass.ai/certificates/1b3cac3c1f274e2b9a3fce909681c1fb

# %% [markdown]
# 3.Certificate course: **Data Visulization with Python**

# %% [markdown]
# ![Screenshot_1.png](data:image/png;base64,...)

# %% [markdown]
# https://courses.cognitiveclass.ai/certificates/75a77e52754949d8af352d371b382109
